# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.columns = [ x.upper() for x in df.columns]

# %%
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.columns = df.columns.str.replace(' ', '_') #replace space with underscore

# %%
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.rename(columns = {'RESPONDENT':'re'}) #to make it permanent inplace = true
# Out:
#           re                                         MAINBRANCH HOBBYIST  \
# 0          1             I am a student who is learning to code      Yes
# 1          2             I am a student who is learning to code       No
# 2          3  I am not primarily a developer, but I write co...      Yes
# 3          4                     I am a developer by profession       No
# 4          5                     I am a developer by profession      Yes
# ...      ...                                                ...      ...
# 88878  88377                                                NaN      Yes
# 88879  88601                                                NaN       No
# 88880  88802                                                NaN       No
# 88881  88816                                                NaN       No
# 88882  88863                                                NaN      Yes
#
#                                              OPENSOURCER  \
# ...

# %%
df.loc[(1),'HOBBYIST']
# Out:
# 'No'

# %%
df.loc[1,('RESPONDENT','MAINBRANCH')] = [1,'fuck']

# %%
df
# Out:
#       RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0              1             I am a student who is learning to code      Yes
# 1              1                                               fuck       No
# 2              3  I am not primarily a developer, but I write co...      Yes
# 3              4                     I am a developer by profession       No
# 4              5                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 88878      88377                                                NaN      Yes
# 88879      88601                                                NaN       No
# 88880      88802                                                NaN       No
# 88881      88816                                                NaN       No
# 88882      88863                                                NaN      Yes
#
# ...

# %%
#second by using at #while setting value just use .loc or .at

# %%
df.at[1,('RESPONDENT','MAINBRANCH')] = [1,'fuck']

# %%
df['HOBBYIST'].str.upper()
# Out:
# 0        YES
# 1         NO
# 2        YES
# 3         NO
# 4        YES
#         ...
# 88878    YES
# 88879     NO
# 88880     NO
# 88881     NO
# 88882    YES
# Name: HOBBYIST, Length: 88883, dtype: object

# %%
df['HOBBYIST'] = df['HOBBYIST'].str.upper()

# %%
df
# Out:
#       RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0              1             I am a student who is learning to code      YES
# 1              1                                               fuck       NO
# 2              3  I am not primarily a developer, but I write co...      YES
# 3              4                     I am a developer by profession       NO
# 4              5                     I am a developer by profession      YES
# ...          ...                                                ...      ...
# 88878      88377                                                NaN      YES
# 88879      88601                                                NaN       NO
# 88880      88802                                                NaN       NO
# 88881      88816                                                NaN       NO
# 88882      88863                                                NaN      YES
#
# ...

# %%
#apply 
#map
#applymap

# %%
df['COUNTRY'].apply(len) #becuase countryh column contaijns missing valueess
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df['COUNTRY'].apply(len)
#
# File F:\anaconda\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File F:\anaconda\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
# ...

# %%
def update_country(OPENSOURCER):
    return OPENSOURCER.upper()

# %%
df['OPENSOURCER'].apply(update_country)  #applying functions
# Out:
# 0                                                    NEVER
# 1                                  LESS THAN ONCE PER YEAR
# 2                                                    NEVER
# 3                                                    NEVER
# 4                               ONCE A MONTH OR MORE OFTEN
#                                ...
# 88878    LESS THAN ONCE A MONTH BUT MORE THAN ONCE PER ...
# 88879                                                NEVER
# 88880                                                NEVER
# 88881                                                NEVER
# 88882                              LESS THAN ONCE PER YEAR
# Name: OPENSOURCER, Length: 88883, dtype: object

# %%
df['OPENSOURCER'] = df['OPENSOURCER'].apply(update_country)

# %%
df
# Out:
#       RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0              1             I am a student who is learning to code      YES
# 1              1                                               fuck       NO
# 2              3  I am not primarily a developer, but I write co...      YES
# 3              4                     I am a developer by profession       NO
# 4              5                     I am a developer by profession      YES
# ...          ...                                                ...      ...
# 88878      88377                                                NaN      YES
# 88879      88601                                                NaN       NO
# 88880      88802                                                NaN       NO
# 88881      88816                                                NaN       NO
# 88882      88863                                                NaN      YES
#
# ...

# %%
df['OPENSOURCER'] = df['OPENSOURCER'].apply(lambda x: x.lower()) #lambda functions

# %%
# Out:
#       RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0              1             I am a student who is learning to code      YES
# 1              1                                               fuck       NO
# 2              3  I am not primarily a developer, but I write co...      YES
# 3              4                     I am a developer by profession       NO
# 4              5                     I am a developer by profession      YES
# ...          ...                                                ...      ...
# 88878      88377                                                NaN      YES
# 88879      88601                                                NaN       NO
# 88880      88802                                                NaN       NO
# 88881      88816                                                NaN       NO
# 88882      88863                                                NaN      YES
#
# ...

# %%
df.apply(len)
# Out:
# RESPONDENT      88883
# MAINBRANCH      88883
# HOBBYIST        88883
# OPENSOURCER     88883
# OPENSOURCE      88883
#                 ...
# SEXUALITY       88883
# ETHNICITY       88883
# DEPENDENTS      88883
# SURVEYLENGTH    88883
# SURVEYEASE      88883
# Length: 85, dtype: int64

# %%
df.apply(len, axis = 'columns')
# Out:
# 0        85
# 1        85
# 2        85
# 3        85
# 4        85
#          ..
# 88878    85
# 88879    85
# 88880    85
# 88881    85
# 88882    85
# Length: 88883, dtype: int64

# %%
df.apply(pd.Series.min)  ## not running because float value bhi hai
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.apply(pd.Series.min)
#
# File F:\anaconda\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File F:\anaconda\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File F:\anaconda\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
# ...

# %%
for col in df.columns:
    try:
        df[col].min()
    except TypeError as e:
        print(col, "->", e)
        print(df[col].map(type).value_counts())
        print()
# Out:
# MAINBRANCH -> '<=' not supported between instances of 'str' and 'float'
# MAINBRANCH
# <class 'str'>      88331
# <class 'float'>      552
# Name: count, dtype: int64
#
# OPENSOURCE -> '<=' not supported between instances of 'str' and 'float'
# OPENSOURCE
# <class 'str'>      86842
# <class 'float'>     2041
# Name: count, dtype: int64
#
# EMPLOYMENT -> '<=' not supported between instances of 'str' and 'float'
# EMPLOYMENT
# <class 'str'>      87181
# <class 'float'>     1702
# Name: count, dtype: int64
#
# COUNTRY -> '<=' not supported between instances of 'str' and 'float'
# COUNTRY
# <class 'str'>      88751
# <class 'float'>      132
# Name: count, dtype: int64
#
# STUDENT -> '<=' not supported between instances of 'str' and 'float'
# STUDENT
# <class 'str'>      87014
# <class 'float'>     1869
# Name: count, dtype: int64
#
# EDLEVEL -> '<=' not supported between instances of 'str' and 'float'
# EDLEVEL
# <class 'str'>      86390
# <class 'float'>     2493
# ...

# %%
df.applymap(len)
# Out:
# C:\Users\garvi\AppData\Local\Temp\ipykernel_17840\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.applymap(len)
#
# File F:\anaconda\Lib\site-packages\pandas\core\frame.py:10549, in DataFrame.applymap(self, func, na_action, **kwargs)
#   10500 """
#   10501 Apply a function to a Dataframe elementwise.
#   10502
#    (...)  10542 1  5  5
#   10543 """
#   10544 warnings.warn(
#   10545     "DataFrame.applymap has been deprecated. Use DataFrame.map instead.",
#   10546     FutureWarning,
#   10547     stacklevel=find_stack_level(),
#   10548 )
# > 10549 return self.map(func, na_action=na_action, **kwargs)
#
# File F:\anaconda\Lib\site-packages\pandas\core\frame.py:10495, in DataFrame.map(self, func, na_action, **kwargs)
# ...
