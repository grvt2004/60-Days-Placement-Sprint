# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df['OpenSourcer'] == 'Never'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 88878    False
# 88879     True
# 88880     True
# 88881     True
# 88882    False
# Name: OpenSourcer, Length: 88883, dtype: bool

# %%
filttttr = (df['OpenSourcer'] == 'Never')

# %%
df.loc[filttttr]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
df[filttttr]  #df[df['OpenSourcer'] == 'Never']
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
df.loc[filttttr, 'Country']
# Out:
# 0        United Kingdom
# 2              Thailand
# 3         United States
# 5                Canada
# 6               Ukraine
#               ...
# 88873               NaN
# 88874               NaN
# 88879               NaN
# 88880               NaN
# 88881               NaN
# Name: Country, Length: 32295, dtype: object

# %%
# & for and also | for or

# %%
filltrr2 = ((df['OpenSourcer'] == 'Never') & (df['Country'] == 'Canada'))

# %%
df.loc[filltrr2]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 11             12             I am a student who is learning to code       No
# 30             31             I am a student who is learning to code       No
# 78             79                     I am a developer by profession      Yes
# 95             96  I used to be a developer by profession, but no...       No
# ...           ...                                                ...      ...
# 88289       88841                     I am a developer by profession      Yes
# 88302       88854                     I am a developer by profession      Yes
# 88317       88870             I am a student who is learning to code      Yes
# 88517       31420                                                NaN      Yes
# 88557       36798                                                NaN      Yes
#
# ...

# %%
df.loc[-filltrr2] #complement
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
filtrr3 = (df['ConvertedComp'] > 700000)

# %%
df.loc[filtrr3]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 31             32                     I am a developer by profession       No
# 57             58                     I am a developer by profession      Yes
# 101           102                     I am a developer by profession       No
# 127           128  I am not primarily a developer, but I write co...      Yes
# 153           155                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88264       88815                     I am a developer by profession      Yes
# 88266       88818                     I am a developer by profession      Yes
# 88315       88868                     I am a developer by profession      Yes
# 88321       88874                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
#
# ...

# %%
df.loc[filtrr3,['Respondent','Country','UndergradMajor','ConvertedComp']]
# Out:
#        Respondent         Country  \
# 31             32   United States
# 57             58   United States
# 101           102   United States
# 127           128  United Kingdom
# 153           155         Germany
# ...           ...             ...
# 88264       88815   United States
# 88266       88818   United States
# 88315       88868         Germany
# 88321       88874   United States
# 88324       88877   United States
#
#                                           UndergradMajor  ConvertedComp
# 31     Information systems, information technology, o...      1100000.0
# 57     Computer science, computer engineering, or sof...      2000000.0
# 101    Computer science, computer engineering, or sof...      2000000.0
# 127    Computer science, computer engineering, or sof...      1000000.0
# 153    Computer science, computer engineering, or sof...       962424.0
# ...                                                  ...            ...
# ...

# %%
#high filter now we filter ouit list of counbtries from this filter
Countriess = ['United States', 'India']
filt44 = df['Country'].isin(Countriess)

# %%
df.loc[filt44, 'Country']
# Out:
# 3        United States
# 7                India
# 9                India
# 12       United States
# 14               India
#              ...
# 88852            India
# 88853            India
# 88859    United States
# 88864            India
# 88877    United States
# Name: Country, Length: 30010, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
#use substring method to filter out only those who knows python

# %%
filtrr55 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filtrr55, ['LanguageWorkedWith','Resposndent']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.loc[filtrr55, ['LanguageWorkedWith','Resposndent']]
#
# File F:\anaconda\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File F:\anaconda\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
#    1375 if self._multi_take_opportunity(tup):
#    1376     return self._multi_take(tup)
# -> 1378 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.loc[filtrr55, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
